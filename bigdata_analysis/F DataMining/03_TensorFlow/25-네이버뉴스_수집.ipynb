# %%
# %%
# 필요한 모듈 참조
import os
import requests
from bs4 import BeautifulSoup


folder_path = "naver_news_folder"


# %%
# IT/과학 : 105, 경제 : 101, 사회 : 102, 생활/문화 : 103, 세계 : 104, 정치 : 100
CATEGORIES = [105, 101, 102, 103, 104, 100]

# 수집하고자 하는 카테고리 번호
CATEGORY = 105

# 수집하고자하는 페이지 범위
PAGES = range(1, 50)

# 네이버 뉴스 URL

URL = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1={category}#&date=%2000:00:00&page={page}'

# %%
# 접속 객체 생성
session = requests.Session()

# 접속객체에 부가정보(header) 삽입하기
session.headers.update({
    "Referer": "",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
})

# %%

# 수집한 뉴스기사의 수를 저장할 변수
counter = 1

# 수집한 뉴스기사를 저장할 파일명
fileName = "{myname}_naver_news_{category}_{counter}.txt"

# 주어진 카테고리에 대해 주어진 페이지 범위만큼 뉴스 수집
for page in PAGES:
    targetUrl = URL.format(category=CATEGORY, page=page)
    print(targetUrl)

    # 생성한 접속객체를 활용하여 뉴스 목록 페이지에 접속
    r = session.get(targetUrl)
    if r.status_code != 200:
    # 에러코드와 에러메시지 출력
      msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
    # 에러를   생성시킴
      raise Exception(msg)

    # 응답결과를 텍스트로 변환
    r.encoding = "euc-kr"
    soup = BeautifulSoup(r.text)

    # 뉴스 기사 제목을 위한 CSS 선택자
    selector = " .sh_item .sh_text .sh_text_headline, #section_body ul li dl dt a"

    # 뉴스기사 제목 추출
    headlines = soup.select(selector)

    # 각 페이지별로 추출된 뉴스기사의 본문 URL
    for h in headlines:
      href = h.attrs['href']

      # 기사 본문에 대한 세부 내용 수정
      if href:
        bodyRes = session.get(href)

        # 기사 본문에 대한 세부 내용 수집
        if bodyRes.status_code != 200:
          # 에러코드와 에러메시지 출력
          msg = "[%d Error] %s 에러가 발생함" % (bodyRes.status_code, bodyRes.reason)
          # 에러를 생성시킴
          raise Exception(msg)

        bodyRes.encoding = "utf-8"
        bodySoup = BeautifulSoup(bodyRes.text)

        #제목
        title = bodySoup.select("#title_area span")[0].text
        print(title)

        #본문
        content = bodySoup.select("#dic_area")[0]

        #본문 요소에 포함되어 있는 불필요한 항목 제거
        for target in content.find_all("span", {"class": "end_photo_org"}):
          target.extract()

        for target in content.find_all("strong", {"class": "media_end_summary"}):
          target.extract()

        for target in content.find_all("table", {"class": "nbd_table"}):
          target.extract()

        for target in content.find_all("div", {"class": "highlightBlock"}):
          target.extract()

        for target in content.find_all("div", {"style": "Display:none;"}):
          target.extract()

        for target in content.find_all("br"):
          target.replace_with("\n")

        contentBody = content.text.strip()
        
        file_path = os.path.join(folder_path, fileName)
        if not os.path.exists(folder_path):
          os.makedirs(folder_path)

        with open(file_path.format(myname= "Yoon", category=CATEGORY, counter=counter), "w", encoding="utf-8") as f:
          f.write(title)
          f.write("\n\n")
          f.write(contentBody)

        counter += 1

        print("%d news article crawled" % counter)
# Out:
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=1
# 네이버, ‘이용자보호 및 자율규제위원회’ 출범
# 2 news article crawled
# 사이버장교 교육했더니 딴길로…사이버국방학 졸업생 17%만 임관
# 3 news article crawled
# 방심위에 '가짜뉴스 신고창구' 마련…심의·구제도 원스톱으로
# 4 news article crawled
# 구글 플레이, 4년 만에 `지스타` 참가…크로스 플랫폼 신작 공개
# 5 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 6 news article crawled
# '화웨이 열풍'에도…아이폰15, 중국서 예약판매 시작 1분만 매진
# 7 news article crawled
# 위성통신 본격 육성 나서는 정부…"2030년 수출 4조원 달성"
# 8 news article crawled
# SKB-넷플릭스, 3년 끈 망사용료 소송 취하‥SKT까지 파트너십
# 9 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=2
# 데브시스터즈, 신작 '쿠키런: 모험의 탑' 지스타서 첫선
# 10 news article crawled
# SKT·넷플릭스, 소송 취하하고 SKT까지 전략적 협력 관계 된다
# 11 news article crawled
# SK㈜ C&C "AI 디지털 혁신 이끌 인재 찾습니다"
# 12 news article crawled
# ‘애플 금지령’도 소용없었다..아이폰15, 中서 1분만에 ‘완판’
# 13 news article crawled
# 네이버 이용자보호 및 자율규제위원회 출범…자율규제 점검
# 14 news article crawled
# "스타링크처럼"…정부, 위성통신 산업에 사활 건다
# 15 news article crawled
# 현대홈쇼핑, KT스카이라이프 송출 중단
# 16 news article crawled
# 유니티 가격 인상 파장…앱·게임 개발자 위한다던 ‘마음’은 어디로
# 17 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=3
# 현대홈쇼핑, 10월20일부터 KT스카이라이프서 빠진다
# 18 news article crawled
# '화웨이 인기'에도…아이폰15, 중국서 불티나게 팔려
# 19 news article crawled
# 한국판 ‘스타링크’ 나온다…4800억 투자해 저궤도 위성 통신망 추진
# 20 news article crawled
# SKB·넷플릭스 '망사용료' 논쟁 3년 만에 종지부
# 21 news article crawled
# 기껏 키웠더니 딴길로…사이버장교 임관율 고작 17%
# 22 news article crawled
# 네이버, 이용자보호 및 자율규제위원회 공식 출범
# 23 news article crawled
# 메가존클라우드 “MSP 업계 최초 부패방지경영시스템 ISO 인증 획득”
# 24 news article crawled
# 방통위, 신속심의 확대 등 가짜뉴스 근절 패스트트랙 가동
# 25 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=4
# "스타링크처럼"…정부, 위성통신 산업에 사활 건다
# 26 news article crawled
# '배틀그라운드 국가대항전'서 한국 첫 우승…MVP에 조기열
# 27 news article crawled
# 구글 플레이, 지스타2023 참가…데브시스터즈·넵튠 신작 공개
# 28 news article crawled
# 망 이용대가 분쟁, 3년만에 마침표…넷플릭스-SKT-SKB, 손 잡았다
# 29 news article crawled
# 방송통신위원회, ‘가짜 뉴스 신속 심의’ 확대 등 근절 대책 발표
# 30 news article crawled
# 네이버 자율규제위원회 출범…제휴사 콘텐츠 평가 자문
# 31 news article crawled
# [베이징 다이어리]'위챗'서 아이폰 누른 화웨이…여전히 불안한 까닭
# 32 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 33 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=5
# SKB·넷플릭스 '망사용료' 소송 끝…EU에 영향 없을듯(종합)
# 34 news article crawled
# 구글플레이, 3년만에 지스타 2023 참가
# 35 news article crawled
# 과기정통부 사이버안전센터, 세종 이전 완료
# 36 news article crawled
# 유니티 가격 인상 파장…앱·게임 개발자 위한다던 ‘마음’은 어디로
# 37 news article crawled
# 네이버, '이용자보호·자율규제위원회' 공식 출범
# 38 news article crawled
# 방심위에 '가짜뉴스 신고창구' 마련…심의·구제도 원스톱으로
# 39 news article crawled
# SK㈜ C&C, AI·클라우드 인재 뽑는다
# 40 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 41 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=6
# SK C&C "AI시대 선도할 인재 모집합니다"
# 42 news article crawled
# SKT, 동반성장지수 11년 연속 최우수…'최우수 명예기업 선정'
# 43 news article crawled
# 윤영찬 “중소 알뜰폰도 자립기반 충분” vs. 업계 “현실과 달라”
# 44 news article crawled
# "아이폰15 사려면?"…韓 10일, 美 5일, 튀르키예 124일 일해야
# 45 news article crawled
# SKT·SKB·넷플릭스, 3년만에 화해…Btv서 넷플 본다(종합)
# 46 news article crawled
# 방통위, 가짜뉴스 유포자 타 매체 활동 제한 검토(종합)
# 47 news article crawled
# '네이버 이용자보호·자율규제위원회' 출범…"자율규제 마련"
# 48 news article crawled
# 구글 플레이, 지스타2023 참가…데브시스터즈·넵튠 신작 공개
# 49 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=7
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 50 news article crawled
# ‘아이폰15 프로 맥스’ 전작대비 수요 높다
# 51 news article crawled
# 방통위, 가짜뉴스 근절 패스트트랙 가동
# 52 news article crawled
# SKT서 넷플릭스 결합상품 나온다…"양사 분쟁 종결"
# 53 news article crawled
# ‘PNC 2023’ 韓 대표팀 우승…조기열 선수 MVP 차지
# 54 news article crawled
# SK㈜ C&C, AI 디지털 미래 혁신 이끌 신입 뽑는다
# 55 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 56 news article crawled
# 저궤도 위성 경쟁 불 붙자…과기정통부, 4800억 투입해 예타 조사
# 57 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=8
# 삼성병원 인증 획득 이끈 더존비즈온…헬스케어 기술력 입증
# 58 news article crawled
# 데브시스터즈, 신작 '쿠키런: 모험의 탑' 지스타 출품
# 59 news article crawled
# 유니티, 게임 개발자 반발에 '설치당 과금' 요금제 변경 예고
# 60 news article crawled
# SKB-넷플릭스 ‘망 사용료 소송’ 취하…“전략적 파트너십 체결”
# 61 news article crawled
# 사이버장교 교육했더니 딴길로…사이버국방학 졸업생 17%만 임관
# 62 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 63 news article crawled
# 메가존클라우드, MSP 업계 최초 부패방지경영시스템 ISO 인증 획득
# 64 news article crawled
# 네이버 '자율규제위' 출범…"독립조직으로 운영"
# 65 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=9
# 中 정부 '금지령' 내렸지만…아이폰 15, 사전예약 1분만에 매진
# 66 news article crawled
# 한국판 스타링크 만든다…과기정통부, ‘저궤도 위성통신’ 육성 2030년 4조원 수출 달성
# 67 news article crawled
# 메가존클라우드 “MSP 업계 최초 부패방지경영시스템 ISO 인증 획득”
# 68 news article crawled
# SKB-넷플릭스, 망사용료 합의점 도출한다
# 69 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 70 news article crawled
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 71 news article crawled
# 네이버 이용자보호 및 자율규제위원회 출범…자율규제 점검
# 72 news article crawled
# 과기정통부, '사이버안전센터' 세종청사로 이전 개소
# 73 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=10
# 클라우드 시장이 수상하다…MSP 3인방 IPO 일정 '이상 기류'
# 74 news article crawled
# SK(주) C&C, AI 혁신 이끌 인재 뽑는다
# 75 news article crawled
# '화웨이 열풍'에도…아이폰15, 중국서 예약판매 시작 1분만 매진
# 76 news article crawled
# SKT서 넷플릭스 결합상품 나온다…"양사 분쟁 종결"
# 77 news article crawled
# 방통위 "방심위에 가짜뉴스 신고 창구 마련…심의·구제 원스톱으로"
# 78 news article crawled
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 79 news article crawled
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 80 news article crawled
# 윤영찬 “중소 알뜰폰도 자립기반 충분” vs. 업계 “현실과 달라”
# 81 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=11
# '과학기술정보통신 사이버안전센터' 세종청사로 이전
# 82 news article crawled
# 네이버 '자율규제위' 출범…"독립조직으로 운영"
# 83 news article crawled
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 84 news article crawled
# 4800억 '위성통신' R&D 나선다..스페이스X 주도 시장 대응
# 85 news article crawled
# SKB-넷플릭스, 3년 끈 망사용료 소송 취하‥SKT까지 파트너십
# 86 news article crawled
# 中 ‘아이폰 금지령’ 소문에도…아이폰 15 매진행렬
# 87 news article crawled
# SK㈜ C＆C, AI·클라우드 인재 채용
# 88 news article crawled
# 구글플레이, 4년 만에 역대 최대 규모 부스로 지스타 2023 참가
# 89 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=12
# "아이폰 안 돼" 中당국 불호령도 '애플 사랑' 못 꺾었다…1분만에 매진
# 90 news article crawled
# 방통위, 가짜뉴스 근절 패스트트랙 가동
# 91 news article crawled
# 과기정통부, 사이버안전센터 나주에서 세종으로 이전
# 92 news article crawled
# 4800억 '위성통신' R&D 나선다..스페이스X 주도 시장 대응
# 93 news article crawled
# 네이버, 독립된 자율규제위원회 꾸렸다…외부전문가 9인 참여
# 94 news article crawled
# 넷플릭스-SK브로드밴드, 3년 넘게 이어온 ‘망이용료’ 소송 취하
# 95 news article crawled
# 크래프톤, 국가대항전 'PNC 2023' 막 내려…대한민국 우승
# 96 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 97 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=13
# SKB-넷플릭스, 망사용료 합의점 도출한다
# 98 news article crawled
# 방송통신위원회, ‘가짜 뉴스 신속 심의’ 확대 등 근절 대책 발표
# 99 news article crawled
# 반복되는 홈쇼핑·유료방송 송출 수수료 갈등, 일단락될까
# 100 news article crawled
# 유니티 “요금제 변동 혼란에 사과...정책 수정할 것”
# 101 news article crawled
# 사이버장교 교육했더니 딴길로…사이버국방학 졸업생 17%만 임관
# 102 news article crawled
# 구글 플레이, 4년 만에 `지스타` 참가…크로스 플랫폼 신작 공개
# 103 news article crawled
# 中 정부 '금지령' 내렸지만…아이폰 15, 사전예약 1분만에 매진
# 104 news article crawled
# 크래프톤, 국가대항전 'PNC 2023' 막 내려…대한민국 우승
# 105 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=14
# "아이폰 안 돼" 中당국 불호령도 '애플 사랑' 못 꺾었다…1분만에 매진
# 106 news article crawled
# 2030년까지 저궤도 위성통신 3기 쏘아 올린다
# 107 news article crawled
# 네이버, 이용자보호 및 자율규제위원회 공식 출범
# 108 news article crawled
# SKB·넷플릭스 '망사용료' 논쟁 3년 만에 종지부
# 109 news article crawled
# 구글플레이, 3년만에 지스타 2023 참가
# 110 news article crawled
# "독립계 알뜰폰 최근 5년간 누적 영업이익 1천억원 수준”
# 111 news article crawled
# 현대홈쇼핑, 내달 20일부터 KT스카이라이프로 송출 중단
# 112 news article crawled
# 방통위, 가짜뉴스 근절 패스트트랙 가동
# 113 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=15
# '아이폰 금지령' 내렸지만‥1분 만에 '매진'
# 114 news article crawled
# 넷플릭스-SK브로드밴드, 3년 넘게 이어온 ‘망이용료’ 소송 취하
# 115 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 116 news article crawled
# '스페이스X·원웹' 겨냥…'위성통신' R&D에 4800억 투자
# 117 news article crawled
# SK㈜ C&C, AI 디지털 미래 혁신 이끌 신입 뽑는다
# 118 news article crawled
# 사이버국방학과 졸업생 23명중 4명만 임관…“대책 필요”
# 119 news article crawled
# 방통위, 가짜뉴스 신속심의·구제제도 이달부터 가동
# 120 news article crawled
# 유니티 “요금제 변동 혼란에 사과...정책 수정할 것”
# 121 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=16
# 방통위, `가짜뉴스 근절` 방안 발표…패스트트랙 가동·포털과 공조 예고
# 122 news article crawled
# 6G·자율주행차 대비…독자 위성통신망 타당성 검토
# 123 news article crawled
# 적에서 동지로…SKB-넷플릭스 ‘망 사용료’ 소송 취하
# 124 news article crawled
# 유니티 “요금제 변동 혼란에 사과...정책 수정할 것”
# 125 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 126 news article crawled
# 삼성병원 인증 획득 이끈 더존비즈온…헬스케어 기술력 입증
# 127 news article crawled
# 현대트랜시스, 9년 연속 ‘동반성장 최우수 기업’ 선정
# 128 news article crawled
# SK C&C, 대졸 신입 뽑는다…AI·클라우드·디지털 팩토리 분야
# 129 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=17
# 푸틴, 위성 기술 이전 약속...北, 3차 위성 발사 성공할까?
# 130 news article crawled
# 적에서 동지로…SKB-넷플릭스 ‘망 사용료’ 소송 취하
# 131 news article crawled
# SKT·KT, 동반성장지수 최우수 등급 획득
# 132 news article crawled
# "아이폰15 사려면?"…韓 10일, 美 5일, 튀르키예 124일 일해야
# 133 news article crawled
# 네이버, 독립된 자율규제위원회 꾸렸다…외부전문가 9인 참여
# 134 news article crawled
# "독립계 알뜰폰 최근 5년간 누적 영업이익 1천억원 수준”
# 135 news article crawled
# 구글 플레이, 지스타2023 참가…데브시스터즈·넵튠 신작 공개
# 136 news article crawled
# 방통위, 가짜뉴스 근절방안 발표…“원스톱 신속심의·구제제도 활성화”
# 137 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=18
# 데브시스터즈, 신작 '쿠키런: 모험의 탑' 지스타서 첫선
# 138 news article crawled
# 넷플릭스-SK브로드밴드, 3년 넘게 이어온 ‘망이용료’ 소송 취하
# 139 news article crawled
# 中 애플 금지령에도...아이폰15, 예약판매 1분 만에 '매진'
# 140 news article crawled
# 방통위, 디지털 플랫폼 자율규제기구 설립 근거 마련
# 141 news article crawled
# 한국판 스타링크 나올까…정부, 저궤도 위성망 검증 나선다
# 142 news article crawled
# SK C&C "AI시대 선도할 인재 모집합니다"
# 143 news article crawled
# 메가존클라우드 “MSP 업계 최초 부패방지경영시스템 ISO 인증 획득”
# 144 news article crawled
# "독립계 알뜰폰 최근 5년간 누적 영업이익 1천억원 수준”
# 145 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=19
# 네이버, 이용자보호 및 자율규제위원회 공식 출범
# 146 news article crawled
# 적에서 동지로…SKB-넷플릭스 ‘망 사용료’ 소송 취하
# 147 news article crawled
# "우주 인터넷 강국으로"…과기정통부 4800억원 규모 사업 예타 신청
# 148 news article crawled
# SKT·KT, 동반성장지수 최우수 등급 획득
# 149 news article crawled
# 방통위, 가짜뉴스 패스트트랙 가동…신고·구제 조치 '원스톱'
# 150 news article crawled
# [뉴겜] 데브시스터즈 프로젝트B, ‘쿠키런:모험의탑’으로 지스타 출격
# 151 news article crawled
# "아이폰15 사려면?"…韓 10일, 美 5일, 튀르키예 124일 일해야
# 152 news article crawled
# '과학기술정보통신 사이버안전센터' 세종청사로 이전
# 153 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=20
# 넷플릭스-SK브로드밴드, 3년 넘게 이어온 ‘망이용료’ 소송 취하
# 154 news article crawled
# 네이버 자율규제위원회 출범…제휴사 콘텐츠 평가 자문
# 155 news article crawled
# '금지령' 아니었나?…아이폰15, 중국서 예약판매 1분 만에 매진
# 156 news article crawled
# 유니티 “요금제 변동 혼란에 사과...정책 수정할 것”
# 157 news article crawled
# 방통위, 가짜뉴스 패스트트랙 가동…신고·구제 조치 '원스톱'
# 158 news article crawled
# SK C&C, 하반기 신입사원 공개채용… ITS·AI 분야 등
# 159 news article crawled
# 구글플레이, 지스타2023 참가…“3년 만에 역대 최대 규모”
# 160 news article crawled
# 반복되는 홈쇼핑·유료방송 송출 수수료 갈등, 일단락될까
# 161 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=21
# 네이버, ‘이용자보호 및 자율규제위원회’ 출범
# 162 news article crawled
# SKT·SKB, 넷플릭스 서비스 제공...망이용대가 합의
# 163 news article crawled
# 2030년까지 저궤도 위성통신 3기 쏘아 올린다
# 164 news article crawled
# ‘아이폰15’ 출시 안 했는데, 불법 보조금 70만원?… 100만원 넘는 통신사 경품도 등장
# 165 news article crawled
# 과기정통부 사이버안전센터, 세종 이전 완료
# 166 news article crawled
# 유니티, 게임 개발자 반발에 '설치당 과금' 요금제 변경 예고
# 167 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 168 news article crawled
# 방통위 "방심위에 가짜뉴스 신고 창구 마련…심의·구제 원스톱으로"
# 169 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=22
# SKT·SKB·넷플릭스, 3년만에 화해…Btv서 넷플 본다(종합)
# 170 news article crawled
# SK C&C, 하반기 신입사원 공개채용… ITS·AI 분야 등
# 171 news article crawled
# 크래프톤, 배틀그라운드 국가대항전 'PNC 2023' 성료...대한민국 우승
# 172 news article crawled
# “배터리 교체 14만원, 말이 돼?” 삼성 2배…아이폰 타령에 허리휜다
# 173 news article crawled
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 174 news article crawled
# "우주 인터넷 강국으로"…과기정통부 4800억원 규모 사업 예타 신청
# 175 news article crawled
# 네이버, 독립된 자율규제위원회 꾸렸다…외부전문가 9인 참여
# 176 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 177 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=23
# 갤Z5 vs 아이폰15…하반기 스마트폰 경쟁 '본격 점화'
# 178 news article crawled
# 현대홈쇼핑, 내달 20일부터 KT스카이라이프로 송출 중단
# 179 news article crawled
# 차세대 먹거리 ‘위성통신망’ 키운다
# 180 news article crawled
# “Btv에 넷플릭스 나온다”…SK-넷플릭스 소송 종료, 왜?
# 181 news article crawled
# 네이버, 이용자보호 및 자율규제위원회 공식 출범
# 182 news article crawled
# 방통위, 가짜뉴스 근절하겠다며 '심의 패스트트랙' 예고
# 183 news article crawled
# 메가존클라우드, 부패방지경영시스템 ISO 인증 획득...MSP 업계 최초
# 184 news article crawled
# "이 게임 사라져, 왜?"…게임엔진 가격인상, 흔들리는 게임업계
# 185 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=24
# 저궤도 위성통신망 구축에 5년간 4800억 투입
# 186 news article crawled
# 구글 플레이, 지스타2023 참가…데브시스터즈·넵튠 신작 공개
# 187 news article crawled
# '배틀그라운드 국가대항전'서 한국 첫 우승…MVP에 조기열
# 188 news article crawled
# 망 이용대가 분쟁, 3년만에 마침표…넷플릭스-SKT-SKB, 손 잡았다
# 189 news article crawled
# 방통위 "방심위에 가짜뉴스 신고 창구 마련…심의·구제 원스톱으로"
# 190 news article crawled
# 사이버장교 교육했더니 딴길로…사이버국방학 졸업생 17%만 임관
# 191 news article crawled
# SK C&C, 대졸 신입 뽑는다…AI·클라우드·디지털 팩토리 분야
# 192 news article crawled
# 메가존클라우드 “MSP 업계 최초 부패방지경영시스템 ISO 인증 획득”
# 193 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=25
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 194 news article crawled
# 네이버 '이용자보호 및 자율규제위원회' 공식 출범
# 195 news article crawled
# 메가존클라우드, 부패방지경영시스템 ISO 인증 획득
# 196 news article crawled
# 한국판 스타링크 만든다…과기정통부, ‘저궤도 위성통신’ 육성 2030년 4조원 수출 달성
# 197 news article crawled
# 데브시스터즈, 협동 액션 '쿠키런: 모험의 탑' 타이틀 공개... 적자 탈출 시동
# 198 news article crawled
# 가짜뉴스 심의 원스톱 처리...방통위, 패스트트랙 가동한다
# 199 news article crawled
# "이 게임 사라져, 왜?"…게임엔진 가격인상, 흔들리는 게임업계
# 200 news article crawled
# SKB-넷플릭스 ‘망 사용료 소송’ 취하…“전략적 파트너십 체결”
# 201 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=26
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 202 news article crawled
# 한국판 ‘스타링크’ 나온다…4800억 투자해 저궤도 위성 통신망 추진
# 203 news article crawled
# 방통위, 가짜뉴스 패스트트랙 가동…신고·구제 조치 '원스톱'
# 204 news article crawled
# 이런 적 없는 유재석도 나섰다…'아이폰15' 혁신에 일침 가한 '삼성빠'
# 205 news article crawled
# SKB-넷플릭스, 3년 끈 망사용료 소송 취하‥SKT까지 파트너십
# 206 news article crawled
# 네이버 자율규제위 출범...어뷰징 규제안 마련
# 207 news article crawled
# 반복되는 홈쇼핑·유료방송 송출 수수료 갈등, 일단락될까
# 208 news article crawled
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 209 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=27
# 아이폰15 중국에서 1분 만에 매진‥'금지령' 안 먹히나?
# 210 news article crawled
# SKT·SKB, 넷플릭스 서비스 제공...망이용대가 합의
# 211 news article crawled
# 네이버, ‘이용자보호 및 자율규제위원회’ 출범
# 212 news article crawled
# 방통위, 선거 악영향 미치는 가짜뉴스 포털에 선제 차단 요청 추진
# 213 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 214 news article crawled
# SK C&C, 하반기 공채 시작…"미래 혁신 이끌 인재 뽑는다"
# 215 news article crawled
# 구글 플레이, 4년 만에 `지스타` 참가…크로스 플랫폼 신작 공개
# 216 news article crawled
# ‘PNC 2023’ 韓 대표팀 우승…조기열 선수 MVP 차지
# 217 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=28
# “2030년까지 저궤도 위성통신 3기 발사할 것”
# 218 news article crawled
# 갤Z5 vs 아이폰15…하반기 스마트폰 경쟁 '본격 점화'
# 219 news article crawled
# “소송보다 협력이 더 이득”… SK브로드밴드, IPO 부담에 넷플릭스와 ‘망 사용료’ 합의
# 220 news article crawled
# 윤영찬 “중소 알뜰폰도 자립기반 충분” vs. 업계 “현실과 달라”
# 221 news article crawled
# 구글플레이, 역대 최대 부스로 지스타 참가...신작 3종 시연
# 222 news article crawled
# [단독] 더존비즈온, 전자신문 인수한다 [넘버스]
# 223 news article crawled
# ‘네이버 이용자보호 및 자율규제위원회’ 공식 출범
# 224 news article crawled
# 방통위, 가짜뉴스 근절방안 발표…“원스톱 신속심의·구제제도 활성화”
# 225 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=29
# “이거 사려고 두 달을 기다려?” 190만원짜리 흰색 아이폰에 난리났다
# 226 news article crawled
# 망 이용대가 분쟁, 3년만에 마침표…넷플릭스-SKT-SKB, 손 잡았다
# 227 news article crawled
# SKT, 동반성장지수 11년 연속 최우수 달성
# 228 news article crawled
# 네이버 이용자보호 및 자율규제위원회 출범…자율규제 점검
# 229 news article crawled
# 게임엔진 '유니티' 요금제 개편 파장... 국회 국정감사 부른다
# 230 news article crawled
# SK C&C, 하반기 공채 시작…"미래 혁신 이끌 인재 뽑는다"
# 231 news article crawled
# 클라우드 시장이 수상하다…MSP 3인방 IPO 일정 '이상 기류'
# 232 news article crawled
# '배틀그라운드 국가대항전'서 한국 첫 우승…MVP에 조기열
# 233 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=30
# 금지령 안먹히네…아이폰 15 中에서 1분만에 매진
# 234 news article crawled
# 위성통신 본격 육성 나서는 정부…"2030년 수출 4조원 달성"
# 235 news article crawled
# 네이버 '이용자보호 및 자율규제위원회' 공식 출범…"자율규제방안 마련할 것"
# 236 news article crawled
# “기껏 사이버장교 키웠더니 졸업자 23명 중 19명(83%) IT기업 등 딴길로”
# 237 news article crawled
# 조승래 의원 "SK-넷플릭스 화해 환영하지만..."
# 238 news article crawled
# 구글 플레이, 4년 만에 `지스타` 참가…크로스 플랫폼 신작 공개
# 239 news article crawled
# "이 게임 사라져, 왜?"…게임엔진 가격인상, 흔들리는 게임업계
# 240 news article crawled
# “자립기반 약하다고? 독립계 알뜰폰 영업익 5년간 천억”..왜?
# 241 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=31
# 데브시스터즈, 신작 '쿠키런: 모험의 탑' 지스타서 첫선
# 242 news article crawled
# 이런 적 없는 유재석도 나섰다…'아이폰15' 혁신에 일침 가한 '삼성빠'
# 243 news article crawled
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 244 news article crawled
# 다크패턴·어뷰징 막는다…네이버, 자율규제위원회 출범
# 245 news article crawled
# 푸틴, 위성 기술 이전 약속...北, 3차 위성 발사 성공할까?
# 246 news article crawled
# 방통위, `가짜뉴스 근절` 방안 발표…패스트트랙 가동·포털과 공조 예고
# 247 news article crawled
# 세기의 '망값' 다툼 종료…SKB-넷플릭스, 합의내용 "비밀"
# 248 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 249 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=32
# SK㈜ C&C, AI·클라우드 인재 뽑는다
# 250 news article crawled
# ‘PNC 2023’ 韓 대표팀 우승…조기열 선수 MVP 차지
# 251 news article crawled
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 252 news article crawled
# 아이폰15 프로 '탈착식' 후면 유리 장착..수리비 훨씬 싸진다 [글로벌 IT슈]
# 253 news article crawled
# 과기부, 'K-위성통신' 3기 육성…4800억 R&D 예타 추진
# 254 news article crawled
# 데브시스터즈, 협동 액션 '쿠키런: 모험의 탑' 타이틀 공개... 적자 탈출 시동
# 255 news article crawled
# SKT·SKB·넷플릭스, 3년만에 화해…Btv서 넷플 본다(종합)
# 256 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 257 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=33
# 데브시스터즈, 협동 액션 '쿠키런: 모험의 탑' 타이틀 공개... 적자 탈출 시동
# 258 news article crawled
# SKT·SKB-넷플릭스, 망사용료 분쟁 끝내고 손잡는다
# 259 news article crawled
# 이런 적 없는 유재석도 나섰다…'아이폰15' 혁신에 일침 가한 '삼성빠'
# 260 news article crawled
# 푸틴, 위성 기술 이전 약속...北, 3차 위성 발사 성공할까?
# 261 news article crawled
# SK C&C, AI·클라우드 신입사원 채용
# 262 news article crawled
# 현대홈쇼핑, 내달 20일부터 KT스카이라이프로 송출 중단
# 263 news article crawled
# 가짜뉴스 심의 원스톱 처리...방통위, 패스트트랙 가동한다
# 264 news article crawled
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 265 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=34
# 세기의 '망값' 다툼 종료…SKB-넷플릭스, 합의내용 "비밀"
# 266 news article crawled
# 방통위, 가짜뉴스 패스트트랙 가동…신고·구제 조치 '원스톱'
# 267 news article crawled
# 유니티, 게임 개발자 반발에 '설치당 과금' 요금제 변경 예고
# 268 news article crawled
# 구글플레이, 3년만에 지스타 2023 참가
# 269 news article crawled
# 네이버, 이용자보호 및 자율규제위원회 공식 출범
# 270 news article crawled
# 위성통신 본격 육성 나서는 정부…"2030년 수출 4조원 달성"
# 271 news article crawled
# 반복되는 홈쇼핑·유료방송 송출 수수료 갈등, 일단락될까
# 272 news article crawled
# 시진핑도 막지 못한 中 애플 사랑…아이폰15 매진행렬
# 273 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=35
# 방통위, 가짜뉴스 신속심의·구제제도 이달부터 가동
# 274 news article crawled
# 세기의 '망값' 다툼 종료…SKB-넷플릭스, 합의내용 "비밀"
# 275 news article crawled
# 네이버, '이용자보호·자율규제위원회' 출범
# 276 news article crawled
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 277 news article crawled
# SK C&C, 하반기 신입사원 공개채용… ITS·AI 분야 등
# 278 news article crawled
# 차세대 먹거리 ‘위성통신망’ 키운다
# 279 news article crawled
# [베이징 다이어리]'위챗'서 아이폰 누른 화웨이…여전히 불안한 까닭
# 280 news article crawled
# “자립기반 약하다고? 독립계 알뜰폰 영업익 5년간 천억”..왜?
# 281 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=36
# "아이폰15 프로맥스 수요, 전작 앞질렀다"
# 282 news article crawled
# 방심위에 '가짜뉴스 신고창구' 마련…심의·구제도 원스톱으로
# 283 news article crawled
# 과기정통부, 사이버안전센터 세종시대 개막
# 284 news article crawled
# 네이버, 이용자보호 및 자율규제위원회 공식 출범
# 285 news article crawled
# SK㈜ C&C, AI·클라우드 인재 뽑는다
# 286 news article crawled
# 게임엔진 '유니티' 요금제 개편 파장... 국회 국정감사 부른다
# 287 news article crawled
# 더존비즈온, 정밀의료 빅데이터 역량 글로벌 입증
# 288 news article crawled
# SKT 5G·Btv 넷플릭스 요금제 나온다…'망값 분쟁' 극적 타결
# 289 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=37
# 화웨이發 애국소비 '일장춘몽' …中 아이폰15 사전판매 1분만에 '완판'
# 290 news article crawled
# 방통위, 신속심의 확대 등 가짜뉴스 근절 패스트트랙 가동
# 291 news article crawled
# 한국판 ‘스타링크’ 나온다…4800억 투자해 저궤도 위성 통신망 추진
# 292 news article crawled
# “Btv에 넷플릭스 나온다”…SK-넷플릭스 소송 종료, 왜?
# 293 news article crawled
# 네이버, '이용자보호·자율규제위원회' 공식 출범
# 294 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 295 news article crawled
# “기껏 사이버장교 키웠더니 졸업자 23명 중 19명(83%) IT기업 등 딴길로”
# 296 news article crawled
# 데브시스터즈, 신작 '쿠키런: 모험의 탑' 지스타 출품
# 297 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=38
# 메가존클라우드, MSP 업계 최초 부패방지경영시스템 ISO 인증 획득
# 298 news article crawled
# 6G·자율주행차 대비…독자 위성통신망 타당성 검토
# 299 news article crawled
# 네이버 '자율규제위원회' 출범…"이용자 보호·품질개선 나선다"
# 300 news article crawled
# 게임엔진 '유니티' 요금제 개편 파장... 국회 국정감사 부른다
# 301 news article crawled
# 넷플릭스, SKT·SKB와 파트너십 체결…망사용료 분쟁 종결
# 302 news article crawled
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 303 news article crawled
# '화웨이 열풍'에도…아이폰15, 중국서 예약판매 시작 1분만 매진
# 304 news article crawled
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 305 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=39
# "이 게임 사라져, 왜?"…게임엔진 가격인상, 흔들리는 게임업계
# 306 news article crawled
# 4년 만에 마침표 찍은 SK브로드밴드·넷플릭스 ‘망 사용료’ 분쟁… 소송 접고 파트너십 체결
# 307 news article crawled
# 위헌·위법 논란 부를 방통위의 '가짜뉴스 근절 방안'
# 308 news article crawled
# 데브시스터즈, ‘쿠키런: 모험의 탑’ 게임명 확정...지스타서 시연
# 309 news article crawled
# "아이폰 안 돼" 中당국 불호령도 '애플 사랑' 못 꺾었다…1분만에 매진
# 310 news article crawled
# 네이버, 독립된 자율규제위원회 꾸렸다…외부전문가 9인 참여
# 311 news article crawled
# 한국판 스타링크 만든다…과기정통부, ‘저궤도 위성통신’ 육성 2030년 4조원 수출 달성
# 312 news article crawled
# 현대홈쇼핑, 10월20일부터 KT스카이라이프서 빠진다
# 313 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=40
# 구글플레이, 역대 최대 부스로 지스타 참가...신작 3종 시연
# 314 news article crawled
# 방통위, 신속심의 확대 등 가짜뉴스 근절 패스트트랙 가동
# 315 news article crawled
# 현대트랜시스, 9년 연속 ‘동반성장 최우수 기업’ 선정
# 316 news article crawled
# “이거 사려고 두 달을 기다려?” 190만원짜리 흰색 아이폰에 난리났다
# 317 news article crawled
# SKB-넷플릭스, 3년 끈 망사용료 소송 취하‥SKT까지 파트너십
# 318 news article crawled
# 2030년까지 저궤도 위성통신 3기 쏘아 올린다
# 319 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 320 news article crawled
# 크래프톤, 배틀그라운드 국가대항전 'PNC 2023' 성료...대한민국 우승
# 321 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=41
# 화웨이 애국소비 열풍에도…아이폰15, 中서 예약판매 1분 만에 매진
# 322 news article crawled
# SKT·SKB, 넷플릭스와 전략적 협력…모든 분쟁도 종결
# 323 news article crawled
# 네이버, `이용자보호·자율규제위원회` 출범
# 324 news article crawled
# '배틀그라운드 국가대항전'서 한국 첫 우승…MVP에 조기열
# 325 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 326 news article crawled
# 데브시스터즈, ‘쿠키런: 모험의 탑’ 게임명 확정...지스타서 시연
# 327 news article crawled
# 방통위, 신속심의 확대 등 가짜뉴스 근절 패스트트랙 가동
# 328 news article crawled
# 한국판 스타링크 만든다…과기정통부, ‘저궤도 위성통신’ 육성 2030년 4조원 수출 달성
# 329 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=42
# 더존비즈온, 정밀의료 빅데이터 플랫폼 역량 세계 입증
# 330 news article crawled
# 방통위, 가짜뉴스 근절 위한 패스트트랙 가동
# 331 news article crawled
# "스타링크처럼"…정부, 위성통신 산업에 사활 건다
# 332 news article crawled
# “배터리 교체 14만원, 말이 돼?” 삼성 2배…아이폰 타령에 허리휜다
# 333 news article crawled
# SKT, 동반성장지수 11년 연속 최우수…'최우수 명예기업 선정'
# 334 news article crawled
# 크래프톤, 배틀그라운드 국가대항전 'PNC 2023' 성료...대한민국 우승
# 335 news article crawled
# “기껏 사이버장교 키웠더니 졸업자 23명 중 19명(83%) IT기업 등 딴길로”
# 336 news article crawled
# "이 게임 사라져, 왜?"…게임엔진 가격인상, 흔들리는 게임업계
# 337 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=43
# ‘가짜뉴스 유포’ 방송사 재허가 유효기간 단축 추진
# 338 news article crawled
# 현대트랜시스, 9년 연속 ‘동반성장 최우수 기업’ 선정
# 339 news article crawled
# 윤영찬 “SK-넷플릭스 합의는 첫걸음…빅테크 무임승차 제도 정비 나설 것”
# 340 news article crawled
# 아이폰15 프로 '탈착식' 후면 유리 장착..수리비 훨씬 싸진다 [글로벌 IT슈]
# 341 news article crawled
# 윤영찬 “중소 알뜰폰도 자립기반 충분” vs. 업계 “현실과 달라”
# 342 news article crawled
# 배그 국가대항전 'PNC 2023', 韓 대표팀 첫 우승
# 343 news article crawled
# “2030년까지 저궤도 위성통신 3기 발사할 것”
# 344 news article crawled
# 유니티 “요금제 변동 혼란에 사과...정책 수정할 것”
# 345 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=44
# "아이폰15 프로맥스 수요, 전작 앞질렀다"
# 346 news article crawled
# 2030년까지 저궤도 위성통신 3기 쏘아 올린다
# 347 news article crawled
# 구글 플레이, 4년 만에 `지스타` 참가…크로스 플랫폼 신작 공개
# 348 news article crawled
# [주요일지] SKB-넷플릭스 '망사용료' 소송 3년6개월만에 전격 합의
# 349 news article crawled
# SK C&C, 생성AI·클라우드 분야 신입사원 채용
# 350 news article crawled
# 네이버 자율규제위 출범…“네이버 스스로 이용자 보호·서비스 품질 개선 추진”
# 351 news article crawled
# SKT, 동반성장지수 11년 연속 최우수…"상생 지속 추진"
# 352 news article crawled
# '과학기술정보통신 사이버안전센터' 세종청사로 이전
# 353 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=45
# "스타링크처럼"…정부, 위성통신 산업에 사활 건다
# 354 news article crawled
# 네이버 '자율규제위' 출범…"독립조직으로 운영"
# 355 news article crawled
# 방통위, 가짜뉴스 신속심의·구제제도 이달부터 가동
# 356 news article crawled
# 윤영찬 “SK-넷플릭스 합의는 첫걸음…빅테크 무임승차 제도 정비 나설 것”
# 357 news article crawled
# '과학기술정보통신 사이버안전센터' 세종으로 이전
# 358 news article crawled
# 아이폰15 프로 '탈착식' 후면 유리 장착..수리비 훨씬 싸진다 [글로벌 IT슈]
# 359 news article crawled
# 현대홈쇼핑, 10월20일부터 KT스카이라이프 전 권역 송출 중단
# 360 news article crawled
# 메가존클라우드, MSP 업계 최초 부패방지경영시스템 ISO 인증 획득
# 361 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=46
# 현대홈쇼핑, 내달 20일부터 KT스카이라이프로 송출 중단
# 362 news article crawled
# 네이버 자율규제위원회 출범…제휴사 콘텐츠 평가 자문
# 363 news article crawled
# 방통위, 신속심의 확대 등 가짜뉴스 근절 패스트트랙 가동
# 364 news article crawled
# “Btv에 넷플릭스 나온다”…SK-넷플릭스 소송 종료, 왜?
# 365 news article crawled
# 아이폰15 중국서 잘 팔리네~판매 시작 1분만에 매진
# 366 news article crawled
# 한국판 스타링크 나올까…정부, 저궤도 위성망 검증 나선다
# 367 news article crawled
# SKT, 동반성장지수 11년 연속 최우수 달성
# 368 news article crawled
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 369 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=47
# 네이버, 독립기구 ‘자율규제위’ 공식 출범
# 370 news article crawled
# 2030년까지 저궤도 위성통신 3기 쏘아 올린다
# 371 news article crawled
# 데브시스터즈 신작 '쿠키런: 모험의 탑' 공개…지스타 출품
# 372 news article crawled
# 4년 만에 마침표 찍은 SK브로드밴드·넷플릭스 ‘망 사용료’ 분쟁… 소송 접고 파트너십 체결
# 373 news article crawled
# 中 ‘아이폰 금지령’ 소문에도…아이폰 15 매진행렬
# 374 news article crawled
# 방통위, 가짜뉴스 근절 패스트트랙 가동
# 375 news article crawled
# 영세 알뜰폰 사업자는 힘들다?…"알뜰폰 영업익 5년간 1000억"
# 376 news article crawled
# 年 20%씩 크던 K클라우드, 비대면 업무 줄어 '고강도 다이어트'
# 377 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=48
# “자립기반 약하다고? 독립계 알뜰폰 영업익 5년간 천억”..왜?
# 378 news article crawled
# 방송통신위원회, ‘가짜 뉴스 신속 심의’ 확대 등 근절 대책 발표
# 379 news article crawled
# SK㈜ C&C, AI·클라우드 인재 뽑는다
# 380 news article crawled
# 데브시스터즈, 신작 '쿠키런: 모험의 탑' 지스타서 첫선
# 381 news article crawled
# 위성통신 본격 육성 나서는 정부…"2030년 수출 4조원 달성"
# 382 news article crawled
# 과기정통부, '사이버안전센터' 세종청사로 이전 개소
# 383 news article crawled
# SK브로드밴드·넷플릭스, 망사용료 소송 마무리
# 384 news article crawled
# “이거 사려고 두 달을 기다려?” 190만원짜리 흰색 아이폰에 난리났다
# 385 news article crawled
# https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105#&date=%2000:00:00&page=49
# 데브시스터즈, ‘쿠키런: 모험의 탑’ 게임명 확정...지스타서 시연
# 386 news article crawled
# "아이폰15 사려면?"…韓 10일, 美 5일, 튀르키예 124일 일해야
# 387 news article crawled
# 2030년까지 저궤도 위성통신 3기 쏘아 올린다
# 388 news article crawled
# 유니티, 게임 개발자 반발에 '설치당 과금' 요금제 변경 예고
# 389 news article crawled
# 네이버, 독립기구 ‘자율규제위’ 공식 출범
# 390 news article crawled
# 세기의 '망값' 다툼 종료…SKB-넷플릭스, 합의내용 "비밀"
# 391 news article crawled
# ‘가짜뉴스 유포’ 방송사 재허가 유효기간 단축 추진
# 392 news article crawled
# 과기정통부, '과학기술정보통신 사이버안전센터' 세종 이전 개소
# 393 news article crawled
