# %% [markdown]
# `statsmodels` 패키지의 설치가 필요하다.

# %%
from matplotlib import pyplot as plt
from pandas import read_excel
import seaborn as sb
from statsmodels.graphics.mosaicplot import mosaic

# %%
titanic = read_excel("https://data.hossam.kr/D01/titanic.xlsx", index_col="PassengerId")
df = titanic.astype({"Survived": "category", "Pclass": "category", 
                     "Sex": "category", "Cabin": "category", "Embarked": "category"})
df.head()
# Out:
#             Survived Pclass  \
# PassengerId
# 1                  0      3
# 2                  1      1
# 3                  1      3
# 4                  1      1
# 5                  0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (7, 4)
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ### 02. Countplot
# 데이터의 빈도를 표현하는 가장 간편한 방법 <br>
# `catplot()`에서 `kind= count`로 고정되있는 것과 같다.
# #### 1. x축에 설정된 집단별 빈도수 확인

# %%
sb.countplot(data=df, x="Pclass")
plt.title("타이타닉호의 각 클래스별, 승객 수")
plt.xticks([0, 1, 2], ['1등급', '2등급', '3등급'])
plt.grid()
plt.show()
plt.close()

# %% [markdown]
# #### 2. 범주 추가

# %%
sb.countplot(data=df, x= "Pclass", hue = 'Sex')
plt.title('타이타닉호의 각 클래스별, 승객 수')
plt.xticks([0,1,2], ['1등급', '2등급', '3등급'])
plt.grid()
plt.show()
plt.close()

# %% [markdown]
# ### 03. 모자이크 그래프
# 막대그래프 외에도 변량이 모두 범주형인 다차원 데이터를 시각화할 떄는 모자이크 그래프(mosaic plot)를 사용하기도 한다.
#
# 모자이크 그래프는 그룹 내의 데이터 백분율을 보여주는 누적 막대그래프이다.
#
# 모자이크 그래프는 변수가 3개이상 일떄도 사용될 수 있다.
#
# 모자이크 그래프는 `statsmodels.graphics.mosaicplot` 패키지의 `mosaic` 함수를 이용해서 그린다.

# %% [markdown]
# #### 1. 한가지 변수에 대한 비율 표시

# %%
mosaic(df, ['Sex'], axes_label=False)

plt.title('타이타닉호 성별 비율', fontsize = 17)
plt.show()
plt.close()

# %% [markdown]
# #### 2. 두 개 이상 범주에 대한 비율 표시

# %%
mosaic(df, ['Sex', 'Survived'], axes_label=False)

plt.title('타이타닉호 성별 생존자', fontsize= 17)
plt.show()
plt.close()

# %% [markdown]
# #### 3. 색상과 표시 라벨 변경하기

# %%
def getColor(key):
    print(key)
    if '1' in key:
        color = 'royalblue'
    else:
        color = 'lightcoral'

    return {'color': color}

# %%
def getLabel(key):
    if 'male' in key:
        gender = '남자'
    else:
        gender = '여자'
    
    if '0' in key:
        sur = '사망'
    else:
        sur = '생존'
    
    label = "%s/%s" % (gender, sur)
    print(key, "->", label)
    return label

# %%
mosaic(df, ['Sex', "Survived"], axes_label= False,
       properties= getColor, labelizer=getLabel)
plt.title('타이타닉호 성별 생존자', fontsize= 17)
plt.show()
plt.close()
# Out:
# ('male', '0')
# ('male', '0') -> 남자/사망
# ('male', '1')
# ('male', '1') -> 남자/생존
# ('female', '0')
# ('female', '0') -> 여자/사망
# ('female', '1')
# ('female', '1') -> 여자/생존

# %% [markdown]
# #### 람다식 사용
# `lambda` 파라미터이름: 리턴값

# %%
mosaic(df, ['Sex', 'Survived'], axes_label=False,
       properties=lambda key: {'color': 'royalblue' if '1' in key else 'lightcoral'},
       labelizer= lambda key:{('female', '1'): '여성/(생존)', ('female', '0'): '여성/(사망)',
                              ('male','1'): '남성/(생존)', ('male','0'): '남성/(사망)'}[key])
plt.title('타이타닉호 성별 생존자', fontsize=17)
plt.show()
plt.close()

# %% [markdown]
# ### 04. 집단별 산점도 그래프

# %%
plt.rcParams['font.size'] = 16                  # 기본 글자크기 설정
plt.rcParams['figure.figsize'] = (20,10)    # 그래프 사이즈 (가로, 세로) inch

# %%
sb.scatterplot(data= df, x='Age', y='Fare', hue='Survived')
plt.title('연령대, 티켓요금에 따른 생존여부 분포')
plt.grid()
plt.show()

# %%
sb.scatterplot(data=df, x='Age', y='Fare', hue=df[['Survived', 'Sex']].apply(tuple,axis=1))
plt.title('연령대, 티켓 요금에 따른 생존여부 분포')
plt.grid()
plt.show()

# %% [markdown]
# ### 05. 산점도 행렬
# 각 변수를 교차로 산점도 그래프를 나열한 형태
#
# 범주형 데이터는 자동으로 제외된다.
#
# 왼쪽 상단에서 오른쪽 하단으로의 중앙에는 각 데이터의 히스토그램이 표시된다.
#
# `diag_kind='kde'` 파라미터를 추가하면 히스토그램 대신 커널밀도추정곡선을 표시한다.

# %%
df
# Out:
#             Survived Pclass  \
# PassengerId
# 1                  0      3
# 2                  1      1
# 3                  1      3
# 4                  1      1
# 5                  0      3
# ...              ...    ...
# 887                0      2
# 888                1      1
# 889                0      3
# 890                1      1
# 891                0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df2 = df.filter(['Survived', 'Pclass','Sex', 'Age','Fare','Embarked']) 
sb.pairplot(df2) # pairplot은 categorical variable은 인식하지 못한다.
plt.show()
plt.close()
